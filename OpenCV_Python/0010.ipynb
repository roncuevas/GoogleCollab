# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('doggie.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (667, 1000, 3)

# %%
img
# Out:
# array([[[ 70, 116,  93],
#         [ 71, 117,  94],
#         [ 71, 117,  94],
#         ...,
#         [  3,  14,   6],
#         [  3,  14,   6],
#         [  2,  13,   3]],
#
#        [[ 71, 117,  94],
#         [ 71, 117,  94],
#         [ 71, 117,  94],
#         ...,
#         [  3,  14,   6],
#         [  3,  14,   6],
#         [  2,  13,   5]],
#
#        [[ 72, 118,  95],
#         [ 72, 118,  95],
#         [ 72, 118,  95],
#         ...,
#         [  3,  14,   6],
#         [  2,  13,   5],
#         [  2,  13,   5]],
#
#        ...,
#
#        [[100, 147, 151],
#         [ 64, 105, 107],
#         [ 70, 105, 101],
#         ...,
#         [ 37,  88,  61],
#         [ 28,  76,  50],
#         [ 23,  74,  47]],
#
#        [[ 83, 129, 140],
#         [ 70, 109, 117],
#         [ 92, 120, 121],
#         ...,
#         [ 51,  96,  70],
#         [ 46,  88,  63],
#         [ 43,  88,  62]],
#
#        [[ 73, 123, 135],
#         [ 72, 111, 120],
#         [ 85, 109, 115],
#         ...,
#         [ 56,  95,  70],
#         [ 51,  87,  63],
#         [ 50,  90,  65]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
#MATPLOTLIB ---> RGB
#OPENCV ---> BGR

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('doggie.jpg', cv2.IMREAD_GRAYSCALE)
img_gray.shape
# Out:
# (667, 1000)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img)

# %%
fix_img.shape
# Out:
# (667, 1000, 3)

# %%
new_img = cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (334, 500, 3)

# %%
new_img = cv2.flip(fix_img,0)
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('newimage.jpg',fix_img)
# Out:
# True
